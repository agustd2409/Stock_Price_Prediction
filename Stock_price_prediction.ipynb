# %%
pip install yfinance
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.
# google-api-core 1.25.1 requires google-auth<2.0dev,>=1.21.1, but you have google-auth 2.23.4 which is incompatible.
# ...
#   Created wheel for peewee: filename=peewee-3.17.5-py3-none-any.whl size=138681 sha256=e9f496a708459c8d37768a283b6d3c9faa28a3b1bbc24106b943885f79f8c834
# ...

# %%
import yfinance as yf

# %%
from datetime import datetime

# %%
end = datetime.now()
start = datetime(end.year-20, end.month, end.day)

# %%
stock = "GOOG"
google_data = yf.download(stock,start,end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
google_data.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2004-08-19  2.490664  2.591785  2.390042  2.499133   2.496292  897427216
# 2004-08-20  2.515820  2.716817  2.503118  2.697639   2.694573  458857488
# 2004-08-23  2.758411  2.826406  2.716070  2.724787   2.721690  366857939
# 2004-08-24  2.770615  2.779581  2.579581  2.611960   2.608991  306396159
# 2004-08-25  2.614201  2.689918  2.587302  2.640104   2.637103  184645512

# %%
google_data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-06-10  176.449997  178.470001  174.380005  176.630005  176.630005
# 2024-06-11  177.720001  178.389999  175.440002  178.190002  178.190002
# 2024-06-12  179.750000  182.080002  177.779999  179.559998  179.559998
# 2024-06-13  177.839996  178.509995  176.660004  176.740005  176.740005
# 2024-06-14  175.852005  178.729996  175.852005  178.369995  178.369995
#
#               Volume
# Date
# 2024-06-10  17122200
# 2024-06-11  14402400
# 2024-06-12  18600400
# 2024-06-13  15956900
# 2024-06-14  11886300

# %%
google_data.shape
# Out:
# (4990, 6)

# %%
google_data.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
google_data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  4990.000000  4990.000000  4990.000000  4990.000000  4990.000000
# mean     44.426449    44.895869    43.982512    44.450434    44.400111
# std      42.135831    42.605660    41.722776    42.178081    42.130780
# min       2.470490     2.534002     2.390042     2.490913     2.488082
# 25%      12.966336    13.127109    12.845415    12.990123    12.975357
# 50%      26.918427    27.114058    26.716399    26.913111    26.882520
# 75%      59.765124    60.217249    59.291499    59.786874    59.718916
# max     179.750000   182.080002   177.779999   179.559998   179.559998
#
#              Volume
# count  4.990000e+03
# mean   1.163430e+08
# std    1.500482e+08
# min    1.584340e+05
# 25%    2.756900e+07
# 50%    5.705506e+07
# 75%    1.438913e+08
# max    1.650833e+09

# %%
google_data.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
google_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4990 entries, 2004-08-19 to 2024-06-14
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       4990 non-null   float64
#  1   High       4990 non-null   float64
#  2   Low        4990 non-null   float64
#  3   Close      4990 non-null   float64
#  4   Adj Close  4990 non-null   float64
#  5   Volume     4990 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 272.9 KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(15,5))
google_data['Adj Close'].plot()
plt.xlabel('years')
plt.ylabel('Adj close')
plt.title('Closing price of Google data')
# Out:
# Text(0.5, 1.0, 'Closing price of Google data')

# %%
def plot_graph(figsize,values,column_name):
    plt.figure()
    values.plot(figsize=figsize)
    plt.xlabel('years')
    plt.ylabel(column_name)
    plt.title(f'{column_name}of Google data')

# %%
google_data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
for column in google_data.columns:
    plot_graph((15,5),google_data[column],column)

# %%
for i in range(2004,2025):
    print(i,list(google_data.index.year).count(i))
# Out:
# 2004 94
# 2005 252
# 2006 251
# 2007 251
# 2008 253
# 2009 252
# 2010 252
# 2011 252
# 2012 250
# 2013 252
# 2014 252
# 2015 252
# 2016 252
# 2017 251
# 2018 251
# 2019 252
# 2020 253
# 2021 252
# 2022 251
# 2023 250
# 2024 115

# %%
google_data['MA_for_250days'] = google_data['Adj Close'].rolling(250).mean()

# %%
google_data['MA_for_250days'][0:250].tail()
# Out:
# Date
# 2005-08-09         NaN
# 2005-08-10         NaN
# 2005-08-11         NaN
# 2005-08-12         NaN
# 2005-08-15    5.028317
# Name: MA_for_250days, dtype: float64

# %%
plot_graph((15,5),google_data['MA_for_250days'],'MA_for_250days')

# %%
plot_graph((15,5),google_data[['Adj Close','MA_for_250days']],'MA_for_250days')

# %%
google_data['MA_for_100days'] = google_data['Adj Close'].rolling(100).mean()
plot_graph((15,5),google_data[['Adj Close','MA_for_100days']],'MA_for_100days')

# %%
plot_graph((15,5),google_data[['Adj Close','MA_for_100days','MA_for_250days']],'MA')

# %%
google_data['precentage_change_cp']= google_data['Adj Close'].pct_change()
google_data[['Adj Close','precentage_change_cp']].head()
# Out:
#             Adj Close  precentage_change_cp
# Date
# 2004-08-19   2.496292                   NaN
# 2004-08-20   2.694573              0.079430
# 2004-08-23   2.721690              0.010064
# 2004-08-24   2.608991             -0.041408
# 2004-08-25   2.637103              0.010775

# %%
plot_graph((15,5),google_data[['precentage_change_cp']],'precentage_change_cp')

# %%
Adj_close_price = google_data[['Adj Close']]

# %%
max(Adj_close_price.values),min(Adj_close_price.values)
# Out:
# (array([179.55999756]), array([2.48808169]))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(Adj_close_price)
scaled_data
# Out:
# C:\Users\sanika\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# array([[4.63690642e-05],
#        [1.16614197e-03],
#        [1.31928457e-03],
#        ...,
#        [1.00000000e+00],
#        [9.84074312e-01],
#        [9.93279553e-01]])

# %%
len(scaled_data)
# Out:
# 4990

# %%
x_data=[]
y_data=[]

for i in range(100,len(scaled_data)):
    x_data.append(scaled_data[i-100:i])
    y_data.append(scaled_data[i])
    
import numpy as np
x_data, y_data = np.array(x_data), np.array(y_data)

# %%
x_data[0],y_data[0]
# Out:
# (array([[4.63690642e-05],
#         [1.16614197e-03],
#         [1.31928457e-03],
#         [6.82825469e-04],
#         [8.41586800e-04],
#         [1.10994113e-03],
#         [8.62661444e-04],
#         [2.81000191e-04],
#         [3.31578260e-04],
#         [3.37218541e-05],
#         [2.10747787e-04],
#         [0.00000000e+00],
#         [2.20584955e-04],
#         [3.21746478e-04],
#         [3.23149479e-04],
#         [7.47455096e-04],
#         [1.05233459e-03],
#         [1.61292658e-03],
#         [1.68457930e-03],
#         [1.96135971e-03],
#         [2.45591773e-03],
#         [2.71864793e-03],
#         [2.50509010e-03],
#         [2.58095586e-03],
#         [2.92377833e-03],
#         [2.78468191e-03],
#         [2.56410234e-03],
#         [3.77238687e-03],
#         [4.36529098e-03],
#         [4.15735189e-03],
#         [4.57603877e-03],
#         [4.92447190e-03],
#         [5.38952246e-03],
#         [5.20828213e-03],
#         [5.45696078e-03],
# ...

# %%
int(len(x_data)*0.7)
# Out:
# 3423

# %%
4990-100-int(len(x_data)*0.7)
# Out:
# 1467

# %%
splitting_len = int(len(x_data)*0.7)
x_train = x_data[:splitting_len]
y_train = y_data[:splitting_len]

x_test = x_data[splitting_len:]
y_test = y_data[splitting_len:]

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3423, 100, 1)
# (3423, 1)
# (1467, 100, 1)
# (1467, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(64,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
# Out:
# WARNING:tensorflow:From C:\Users\sanika\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
 model.compile(optimizer='adam',loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From C:\Users\sanika\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(x_train,y_train,batch_size=1, epochs=2)
# Out:
# Epoch 1/2
# WARNING:tensorflow:From C:\Users\sanika\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 3423/3423 [==============================] - 145s 41ms/step - loss: 1.1481e-04
# Epoch 2/2
# 3423/3423 [==============================] - 108s 31ms/step - loss: 6.0726e-05

# %%
 model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100, 128)          66560
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 25)                1625
#
#  dense_1 (Dense)             (None, 1)                 26
#
# ...
# Total params: 117619 (459.45 KB)
# Trainable params: 117619 (459.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
predictions = model.predict(x_test)
# Out:
# 46/46 [==============================] - 2s 42ms/step

# %%
predictions
# Out:
# array([[0.35665834],
#        [0.35312563],
#        [0.3505417 ],
#        ...,
#        [1.0269649 ],
#        [1.0333114 ],
#        [1.0290884 ]], dtype=float32)

# %%
inv_predictions = scaler.inverse_transform(predictions)
inv_predictions
# Out:
# array([[ 65.64226 ],
#        [ 65.016716],
#        [ 64.55917 ],
#        ...,
#        [184.33472 ],
#        [185.4585  ],
#        [184.71072 ]], dtype=float32)

# %%
inv_y_test = scaler.inverse_transform(y_test)
inv_y_test
# Out:
# array([[ 60.25593185],
#        [ 59.97974777],
#        [ 60.31985855],
#        ...,
#        [179.55999756],
#        [176.74000549],
#        [178.36999512]])

# %%
rmse=np.sqrt(np.mean((inv_predictions-inv_y_test)**2))

# %%
rmse
# Out:
# 7.254597139620727

# %%
import pandas as pd

# %%
plotting_data = pd.DataFrame(
    {
        'original_test_data': inv_y_test.reshape(-1),
        'predictions': inv_predictions.reshape(-1)
    },
    index = google_data.index[splitting_len+100:]
)
plotting_data.head()
# Out:
#             original_test_data  predictions
# Date
# 2018-08-16           60.255932    65.642258
# 2018-08-17           59.979748    65.016716
# 2018-08-20           60.319859    64.559174
# 2018-08-21           60.012711    64.544106
# 2018-08-22           60.297886    64.505096

# %%
plot_graph((15,6),plotting_data,'test_data')

# %%
plot_graph((15,6),pd.concat([Adj_close_price[:splitting_len+100],plotting_data],axis= 0),'whole_data')

# %%
model.save("Latest_stock_price_model.keras")
